# %% [markdown]
#  ***this is the GLANN implementation step by step ***

# %%
# !pwd
# Out:
# /content

# %%
# !ls

# %%
# !git clone https://github.com/yedidh/glann.git
# Out:
# Cloning into 'glann'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 56 (delta 22), reused 6 (delta 0), pack-reused 0
# Unpacking objects: 100% (56/56), done.

# %%
pip install numpy scipy pytorch torchvision
# Out:
# ...
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ...
#     Running setup.py install for pytorch ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-h3xbjfc6/pytorch/setup.py'"'"'; __file__='"'"'/tmp/pip-install-h3xbjfc6/pytorch/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-qn7jr0a8/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.

# %%
pip install fbpca
# Out:
# ...
#   Created wheel for fbpca: filename=fbpca-1.0-cp36-none-any.whl size=11376 sha256=ee6066b478bd46ec44b5a3e4d0e10ca78858ed873cf1bc05298c9c8514747d07
#   Stored in directory: /root/.cache/pip/wheels/53/a2/dd/9b66cf53dbc58cec1e613d216689e5fa946d3e7805c30f60dc
# Successfully built fbpca
# ...

# %%
pip install faiss-gpu
# Out:
# ...
#      |████████████████████████████████| 41.0MB 68kB/s
# ...

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as dsets

# %%
train_dataset = dsets.MNIST(root='./data',
                            train=True,
                            transform=transforms.ToTensor(),
                            download=True)

test_dataset = dsets.MNIST(root='./data',
                           train=False,
                           transform=transforms.ToTensor())
# Out:
# 0it [00:00, ?it/s]
# ...
# 9920512it [00:01, 9391396.44it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#   0%|          | 0/28881 [00:00<?, ?it/s]
# ...
# 32768it [00:00, 137188.17it/s]
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# ...
# 1654784it [00:00, 2348283.70it/s]
# 8192it [00:00, 54823.48it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# ...
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!

# %%
cd glann/
# Out:
# /content/glann

# %%
pip install python-mnist
# Out:
# ...
#   Created wheel for python-mnist: filename=python_mnist-0.6-py2.py3-none-any.whl size=11662 sha256=10fc58521e8ac36acbf433af64b7b243c90ad6b0ca95fa5477b1b87dd9eb3b4e
#   Stored in directory: /root/.cache/pip/wheels/28/29/36/408f83545a511c43d03ef997a1dc99b49ccd5f9f306ed92468
# Successfully built python-mnist
# ...

# %% [markdown]
# Edit prepare_mnist.py with the correct path to the data.
# change "NULL" to "../data/MNIST/raw"

# %%
# !python prepare_mnist.py

# %%
# !python train_glo.py configs/mnist.yaml

# %%
# !python train_icp.py configs/mnist.yaml

# %%
# !python test_fid.py configs/mnist.yaml
